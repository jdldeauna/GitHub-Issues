# %%
import intake
import xarray
import zarr
import dask

from intake import open_catalog

# %% [markdown]
# ### Hydro

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/hydro.yaml")
list(cat)
# Out:
# ['cgiar_pet', 'hydrosheds_dir', 'hydrosheds_acc']

# %%
ds  = cat["cgiar_pet"].to_dask()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-08dc5691d513> in <module>
# ----> 1 ds  = cat["cgiar_pet"].to_dask()
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake_xarray/base.py in to_dask(self)
#      67     def to_dask(self):
#      68         """Return xarray object where variables are dask arrays"""
# ---> 69         return self.read_chunked()
#      70
#      71     def close(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake_xarray/base.py in read_chunked(self)
#      42     def read_chunked(self):
#      43         """Return xarray object (which will have chunks)"""
# ---> 44         self._load_metadata()
#      45         return self._ds
#      46
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/source/base.py in _load_metadata(self)
#     234         """load metadata only if needed"""
#     235         if self._schema is None:
# --> 236             self._schema = self._get_schema()
#     237             self.dtype = self._schema.dtype
#     238             self.shape = self._schema.shape
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake_xarray/base.py in _get_schema(self)
#      16
#      17         if self._ds is None:
# ---> 18             self._open_dataset()
#      19
#      20             metadata = {
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake_xarray/xzarr.py in _open_dataset(self)
#      29
#      30         self._mapper = get_mapper(self.urlpath, **self.storage_options)
# ---> 31         self._ds = xr.open_zarr(self._mapper, **self.kwargs)
#      32
#      33     def close(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/xarray/backends/zarr.py in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, **kwargs)
#     677         backend_kwargs=backend_kwargs,
#     678         decode_timedelta=decode_timedelta,
# --> 679         use_cftime=use_cftime,
#     680     )
#     681
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     552
#     553         opener = _get_backend_cls(engine)
# --> 554         store = opener(filename_or_obj, **extra_kwargs, **backend_kwargs)
#     555
#     556     with close_on_error(store):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/xarray/backends/zarr.py in open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region)
#     322             zarr_group = zarr.open_consolidated(store, **open_kwargs)
#     323         else:
# --> 324             zarr_group = zarr.open_group(store, **open_kwargs)
#     325         return cls(zarr_group, consolidate_on_close, append_dim, write_region)
#     326
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/zarr/hierarchy.py in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options)
#    1161
#    1162     if mode in ['r', 'r+']:
# -> 1163         if contains_array(store, path=path):
#    1164             raise ContainsArrayError(path)
#    1165         elif not contains_group(store, path=path):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/zarr/storage.py in contains_array(store, path)
#      93     prefix = _path_to_prefix(path)
#      94     key = prefix + array_meta_key
# ---> 95     return key in store
#      96
#      97
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/fsspec/mapping.py in __contains__(self, key)
#     168         """Does key exist in mapping?"""
#     169         path = self._key_to_str(key)
# --> 170         return self.fs.exists(path) and self.fs.isfile(path)
#     171
#     172     def __reduce__(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      70     def wrapper(*args, **kwargs):
#      71         self = obj or args[0]
# ---> 72         return sync(self.loop, func, *args, **kwargs)
#      73
#      74     return wrapper
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      51     event.wait(timeout)
#      52     if isinstance(result[0], BaseException):
# ---> 53         raise result[0]
#      54     return result[0]
#      55
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      18         coro = asyncio.wait_for(coro, timeout=timeout)
#      19     try:
# ---> 20         result[0] = await coro
#      21     except Exception as ex:
#      22         result[0] = ex
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/fsspec/asyn.py in _exists(self, path)
#     254     async def _exists(self, path):
#     255         try:
# --> 256             await self._info(path)
#     257             return True
#     258         except FileNotFoundError:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/gcsfs/core.py in _info(self, path, **kwargs)
#     828         # Check exact file path
#     829         try:
# --> 830             return await self._get_object(path)
#     831         except FileNotFoundError:
#     832             pass
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/gcsfs/core.py in _get_object(self, path)
#     610         # fall back to a bucket list + filter to object name (storage.objects.list).
#     611         try:
# --> 612             res = await self._call("GET", "b/{}/o/{}", bucket, key, json_out=True)
#     613         except OSError as e:
#     614             if not str(e).startswith("Forbidden"):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/gcsfs/core.py in _call(self, method, path, json_out, info_out, *args, **kwargs)
#     537                     contents = await r.read()
#     538
# --> 539                 self.validate_response(status, contents, path, headers)
#     540                 break
#     541             except (HttpError, RequestException, GoogleAuthError, ChecksumError) as e:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/gcsfs/core.py in validate_response(self, status, content, path, headers)
#    1315                 raise ProxyError()
#    1316             elif "invalid" in str(msg):
# -> 1317                 raise ValueError("Bad Request: %s\n%s" % (path, msg))
#    1318             elif error:
#    1319                 raise HttpError(error)
#
# ValueError: Bad Request: https://www.googleapis.com/storage/v1/b/pangeo-cgiar-pet/o/.zarray
# User project specified in the request is invalid.

# %% [markdown]
# ### Master list

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/master.yaml")
list(cat)
# Out:
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# <ipython-input-4-7b1b39cce233> in <module>
# ----> 1 cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/master.yaml")
#       2 list(cat)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/__init__.py in open_catalog(uri, **kwargs)
#     165         raise ValueError('Unknown catalog driver (%s), supply one of: %s'
#     166                          % (driver, list(sorted(registry))))
# --> 167     return registry[driver](uri, **kwargs)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in __init__(self, path, autoreload, **kwargs)
#     566         self.filesystem = kwargs.pop('fs', None)
#     567         self.access = "name" not in kwargs
# --> 568         super(YAMLFileCatalog, self).__init__(**kwargs)
#     569
#     570     def _load(self, reload=False):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in __init__(self, entries, name, description, metadata, ttl, getenv, getshell, persist_mode, storage_options)
#      98         self.updated = time.time()
#      99         self._entries = entries if entries is not None else self._make_entries_container()
# --> 100         self.force_reload()
#     101
#     102     @classmethod
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in force_reload(self)
#     156         """Imperative reload data now"""
#     157         self.updated = time.time()
# --> 158         self._load()
#     159
#     160     def reload(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in _load(self, reload)
#     601                 logger.warning("Use of '!template' deprecated - fixing")
#     602                 text = text.replace('!template ', '')
# --> 603             self.parse(text)
#     604
#     605     def add(self, source, name=None, path=None, storage_options=None):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in parse(self, text)
#     670         """
#     671         self.text = text
# --> 672         data = yaml_load(self.text)
#     673
#     674         if data is None:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/utils.py in yaml_load(stream)
#      76     """Parse YAML in a context where duplicate keys raise exception"""
#      77     with no_duplicate_yaml():
# ---> 78         return yaml.safe_load(stream)
#      79
#      80
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/__init__.py in safe_load(stream)
#     160     to be safe for untrusted input.
#     161     """
# --> 162     return load(stream, SafeLoader)
#     163
#     164 def safe_load_all(stream):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/__init__.py in load(stream, Loader)
#     112     loader = Loader(stream)
#     113     try:
# --> 114         return loader.get_single_data()
#     115     finally:
#     116         loader.dispose()
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/constructor.py in get_single_data(self)
#      47     def get_single_data(self):
#      48         # Ensure that the stream contains a single document and construct it.
# ---> 49         node = self.get_single_node()
#      50         if node is not None:
#      51             return self.construct_document(node)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in get_single_node(self)
#      34         document = None
#      35         if not self.check_event(StreamEndEvent):
# ---> 36             document = self.compose_document()
#      37
#      38         # Ensure that the stream contains no more documents.
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_document(self)
#      53
#      54         # Compose the root node.
# ---> 55         node = self.compose_node(None, None)
#      56
#      57         # Drop the DOCUMENT-END event.
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      62
#      63     def compose_node(self, parent, index):
# ---> 64         if self.check_event(AliasEvent):
#      65             event = self.get_event()
#      66             anchor = event.anchor
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/parser.py in check_event(self, *choices)
#      96         if self.current_event is None:
#      97             if self.state:
# ---> 98                 self.current_event = self.state()
#      99         if self.current_event is not None:
#     100             if not choices:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/parser.py in parse_block_mapping_value(self)
#     447         if self.check_token(ValueToken):
#     448             token = self.get_token()
# --> 449             if not self.check_token(KeyToken, ValueToken, BlockEndToken):
#     450                 self.states.append(self.parse_block_mapping_key)
#     451                 return self.parse_block_node_or_indentless_sequence()
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in check_token(self, *choices)
#     114         # Check if the next token is one of the given types.
#     115         while self.need_more_tokens():
# --> 116             self.fetch_more_tokens()
#     117         if self.tokens:
#     118             if not choices:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in fetch_more_tokens(self)
#     249         # Is it a double quoted scalar?
#     250         if ch == '\"':
# --> 251             return self.fetch_double()
#     252
#     253         # It must be a plain scalar then.
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in fetch_double(self)
#     653
#     654     def fetch_double(self):
# --> 655         self.fetch_flow_scalar(style='"')
#     656
#     657     def fetch_flow_scalar(self, style):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in fetch_flow_scalar(self, style)
#     664
#     665         # Scan and add SCALAR.
# --> 666         self.tokens.append(self.scan_flow_scalar(style))
#     667
#     668     def fetch_plain(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in scan_flow_scalar(self, style)
#    1149         chunks.extend(self.scan_flow_scalar_non_spaces(double, start_mark))
#    1150         while self.peek() != quote:
# -> 1151             chunks.extend(self.scan_flow_scalar_spaces(double, start_mark))
#    1152             chunks.extend(self.scan_flow_scalar_non_spaces(double, start_mark))
#    1153         self.forward()
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in scan_flow_scalar_spaces(self, double, start_mark)
#    1237         if ch == '\0':
#    1238             raise ScannerError("while scanning a quoted scalar", start_mark,
# -> 1239                     "found unexpected end of stream", self.get_mark())
#    1240         elif ch in '\r\n\x85\u2028\u2029':
#    1241             line_break = self.scan_line_break()
#
# ScannerError: while scanning a quoted scalar
#   in "<unicode string>", line 13, column 13:
#           path: "{{CATALOG_DI
#                 ^
# found unexpected end of stream
#   in "<unicode string>", line 13, column 26:
#           path: "{{CATALOG_DI
#                              ^

# %% [markdown]
# ### Ocean

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean.yaml")
list(cat)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-5-e082b07419f5> in <module>
# ----> 1 cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean.yaml")
#       2 list(cat)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/__init__.py in open_catalog(uri, **kwargs)
#     165         raise ValueError('Unknown catalog driver (%s), supply one of: %s'
#     166                          % (driver, list(sorted(registry))))
# --> 167     return registry[driver](uri, **kwargs)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in __init__(self, path, autoreload, **kwargs)
#     566         self.filesystem = kwargs.pop('fs', None)
#     567         self.access = "name" not in kwargs
# --> 568         super(YAMLFileCatalog, self).__init__(**kwargs)
#     569
#     570     def _load(self, reload=False):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in __init__(self, entries, name, description, metadata, ttl, getenv, getshell, persist_mode, storage_options)
#      98         self.updated = time.time()
#      99         self._entries = entries if entries is not None else self._make_entries_container()
# --> 100         self.force_reload()
#     101
#     102     @classmethod
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in force_reload(self)
#     156         """Imperative reload data now"""
#     157         self.updated = time.time()
# --> 158         self._load()
#     159
#     160     def reload(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in _load(self, reload)
#     601                 logger.warning("Use of '!template' deprecated - fixing")
#     602                 text = text.replace('!template ', '')
# --> 603             self.parse(text)
#     604
#     605     def add(self, source, name=None, path=None, storage_options=None):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in parse(self, text)
#     682             raise exceptions.ValidationError(
#     683                 "Catalog '{}' has validation errors:\n\n{}"
# --> 684                 "".format(self.path, "\n".join(result.errors)), result.errors)
#     685
#     686         cfg = result.data
#
# ValidationError: Catalog 'https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean.yaml' has validation errors:
#
# ("missing required key 'driver'", {'description': 'Estimating the Circulation and Climate of the Ocean (ECCO) State Estimate Ve'})

# %% [markdown]
# ### Atmosphere

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/atmosphere.yaml")
list(cat)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-6-233caba71251> in <module>
# ----> 1 cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/atmosphere.yaml")
#       2 list(cat)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/__init__.py in open_catalog(uri, **kwargs)
#     165         raise ValueError('Unknown catalog driver (%s), supply one of: %s'
#     166                          % (driver, list(sorted(registry))))
# --> 167     return registry[driver](uri, **kwargs)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in __init__(self, path, autoreload, **kwargs)
#     566         self.filesystem = kwargs.pop('fs', None)
#     567         self.access = "name" not in kwargs
# --> 568         super(YAMLFileCatalog, self).__init__(**kwargs)
#     569
#     570     def _load(self, reload=False):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in __init__(self, entries, name, description, metadata, ttl, getenv, getshell, persist_mode, storage_options)
#      98         self.updated = time.time()
#      99         self._entries = entries if entries is not None else self._make_entries_container()
# --> 100         self.force_reload()
#     101
#     102     @classmethod
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in force_reload(self)
#     156         """Imperative reload data now"""
#     157         self.updated = time.time()
# --> 158         self._load()
#     159
#     160     def reload(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in _load(self, reload)
#     601                 logger.warning("Use of '!template' deprecated - fixing")
#     602                 text = text.replace('!template ', '')
# --> 603             self.parse(text)
#     604
#     605     def add(self, source, name=None, path=None, storage_options=None):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in parse(self, text)
#     682             raise exceptions.ValidationError(
#     683                 "Catalog '{}' has validation errors:\n\n{}"
# --> 684                 "".format(self.path, "\n".join(result.errors)), result.errors)
#     685
#     686         cfg = result.data
#
# ValidationError: Catalog 'https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/atmosphere.yaml' has validation errors:
#
# ("value 'None' is not expected type 'dict'", {'description': '3D fields from a near-global Aquaplanet Simulation with the System for Atmospheric Modeling', 'metadata': {'tags': ['atmosphere', 'model']}, 'driver': 'zarr', 'args': None}, 'args')

# %% [markdown]
# ### Climate

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/climate.yaml")
list(cat)
# Out:
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# <ipython-input-7-4782b239e2b0> in <module>
# ----> 1 cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/climate.yaml")
#       2 list(cat)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/__init__.py in open_catalog(uri, **kwargs)
#     165         raise ValueError('Unknown catalog driver (%s), supply one of: %s'
#     166                          % (driver, list(sorted(registry))))
# --> 167     return registry[driver](uri, **kwargs)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in __init__(self, path, autoreload, **kwargs)
#     566         self.filesystem = kwargs.pop('fs', None)
#     567         self.access = "name" not in kwargs
# --> 568         super(YAMLFileCatalog, self).__init__(**kwargs)
#     569
#     570     def _load(self, reload=False):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in __init__(self, entries, name, description, metadata, ttl, getenv, getshell, persist_mode, storage_options)
#      98         self.updated = time.time()
#      99         self._entries = entries if entries is not None else self._make_entries_container()
# --> 100         self.force_reload()
#     101
#     102     @classmethod
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/base.py in force_reload(self)
#     156         """Imperative reload data now"""
#     157         self.updated = time.time()
# --> 158         self._load()
#     159
#     160     def reload(self):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in _load(self, reload)
#     601                 logger.warning("Use of '!template' deprecated - fixing")
#     602                 text = text.replace('!template ', '')
# --> 603             self.parse(text)
#     604
#     605     def add(self, source, name=None, path=None, storage_options=None):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/catalog/local.py in parse(self, text)
#     670         """
#     671         self.text = text
# --> 672         data = yaml_load(self.text)
#     673
#     674         if data is None:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/intake/utils.py in yaml_load(stream)
#      76     """Parse YAML in a context where duplicate keys raise exception"""
#      77     with no_duplicate_yaml():
# ---> 78         return yaml.safe_load(stream)
#      79
#      80
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/__init__.py in safe_load(stream)
#     160     to be safe for untrusted input.
#     161     """
# --> 162     return load(stream, SafeLoader)
#     163
#     164 def safe_load_all(stream):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/__init__.py in load(stream, Loader)
#     112     loader = Loader(stream)
#     113     try:
# --> 114         return loader.get_single_data()
#     115     finally:
#     116         loader.dispose()
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/constructor.py in get_single_data(self)
#      47     def get_single_data(self):
#      48         # Ensure that the stream contains a single document and construct it.
# ---> 49         node = self.get_single_node()
#      50         if node is not None:
#      51             return self.construct_document(node)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in get_single_node(self)
#      34         document = None
#      35         if not self.check_event(StreamEndEvent):
# ---> 36             document = self.compose_document()
#      37
#      38         # Ensure that the stream contains no more documents.
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_document(self)
#      53
#      54         # Compose the root node.
# ---> 55         node = self.compose_node(None, None)
#      56
#      57         # Drop the DOCUMENT-END event.
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     125         if anchor is not None:
#     126             self.anchors[anchor] = node
# --> 127         while not self.check_event(MappingEndEvent):
#     128             #key_event = self.peek_event()
#     129             item_key = self.compose_node(node, None)
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/parser.py in check_event(self, *choices)
#      96         if self.current_event is None:
#      97             if self.state:
# ---> 98                 self.current_event = self.state()
#      99         if self.current_event is not None:
#     100             if not choices:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/parser.py in parse_block_mapping_key(self)
#     426
#     427     def parse_block_mapping_key(self):
# --> 428         if self.check_token(KeyToken):
#     429             token = self.get_token()
#     430             if not self.check_token(KeyToken, ValueToken, BlockEndToken):
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in check_token(self, *choices)
#     114         # Check if the next token is one of the given types.
#     115         while self.need_more_tokens():
# --> 116             self.fetch_more_tokens()
#     117         if self.tokens:
#     118             if not choices:
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in fetch_more_tokens(self)
#     171         # Is it the end of stream?
#     172         if ch == '\0':
# --> 173             return self.fetch_stream_end()
#     174
#     175         # Is it a directive?
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in fetch_stream_end(self)
#     375
#     376         # Reset simple keys.
# --> 377         self.remove_possible_simple_key()
#     378         self.allow_simple_key = False
#     379         self.possible_simple_keys = {}
#
# ~/miniconda3/envs/test_intake/lib/python3.7/site-packages/yaml/scanner.py in remove_possible_simple_key(self)
#     317             if key.required:
#     318                 raise ScannerError("while scanning a simple key", key.mark,
# --> 319                         "could not find expected ':'", self.get_mark())
#     320
#     321             del self.possible_simple_keys[self.flow_level]
#
# ScannerError: while scanning a simple key
#   in "<unicode string>", line 13, column 5:
#         met
#         ^
# could not find expected ':'
#   in "<unicode string>", line 13, column 8:
#         met
#            ^

# %% [markdown]
# ### Test intake with intake-esm

# %%
cat_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6-noQC.json"
col = intake.open_esm_datastore(cat_url)
cat = col.search(table_id='Omon', 
                 experiment_id=['historical'],
                 variable_id=['thetao'],
                 member_id=['r1i1p1f1'],
                 grid_label='gn',
                 source_id=['CMCC-ESM2']
                )
cat
# Out:
# <p><strong>pangeo-cmip6 catalog with 1 dataset(s) from 1 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>status</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>severity</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>issue_url</th>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>
